# %%
pip install SpeechRecognition
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.9 MB 328.9 kB/s eta 0:01:39
#     --------------------------------------- 0.5/32.9 MB 328.9 kB/s eta 0:01:39
#     --------------------------------------- 0.8/32.9 MB 381.3 kB/s eta 0:01:25
#     --------------------------------------- 0.8/32.9 MB 381.3 kB/s eta 0:01:25
#     --------------------------------------- 0.8/32.9 MB 381.3 kB/s eta 0:01:25
#     --------------------------------------- 0.8/32.9 MB 381.3 kB/s eta 0:01:25
#     --------------------------------------- 0.8/32.9 MB 381.3 kB/s eta 0:01:25
# ...

# %%
pip install pyttsx3
# Out:
#   Cell In[5], line 2
#     pip install SpeechRecognition
#         ^
# SyntaxError: invalid syntax

# %%
import pyttsx3

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Your text
text = "my name is ahmad"

# Speak the text
engine.say(text)

# Wait for the speaking to finish
engine.runAndWait()

# %%
import pyttsx3    #allows Python to convert text into spoken audio.

engine = pyttsx3.init() #initialize the voices 

voices = engine.getProperty('voices')      #Retrieves a list of all available voices installed on your system (e.g., male and female voices).
male_voice = voices[0].id    # male voice (e.g., Microsoft David)
female_voice = voices[1].id  # female voice (e.g., Microsoft Zira)

def speak(text, voice_id):
    engine.setProperty('voice', voice_id)
    engine.say(text)
    engine.runAndWait()

# Male voice example
speak("Hello, this is the male voice speaking.", male_voice)

# Female voice example
speak("Hello, this is the female voice speaking.", female_voice)

# %%
import speech_recognition as sr
from datetime import datetime

def save_note(text):
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"note_{timestamp}.txt"
    with open(filename, "w", encoding='utf-8') as f:
        f.write(text)
    print(f"✅ Note saved as: {filename}")

def SpeachTOText():
    recognizer = sr.Recognizer()
    mic = sr.Microphone()

    print("🎙️ Speak your note. Press Ctrl+C to stop.")
    with mic as source:
        recognizer.adjust_for_ambient_noise(source)
        print("🔴 Listening...")
        audio = recognizer.listen(source)

    try:
        print("🧠 Transcribing...")
        text = recognizer.recognize_google(audio)
        print(f"📝 You said: {text}")
        save_note(text)
    except sr.UnknownValueError:
        print("❌ Could not understand your speech.")
    except sr.RequestError as e:
        print(f"🚫 Speech recognition service error: {e}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 32
#      29         print(f"🚫 Speech recognition service error: {e}")
#      31 if __name__ == "__main__":
# ---> 32     main()
#
# NameError: name 'main' is not defined

# %%
# Open webcam (0 = default camera)
cap = cv2.VideoCapture(0)

# Check if the webcam opens successfully
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run object detection
    results = model(frame)

    # Visualize results on the frame
    annotated_frame = results[0].plot()

    # Show the output
    cv2.imshow("YOLOv8 Object Detection", annotated_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\mahma\AppData\Local\Programs\Python\Python312\Lib\tempfile.py:256, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     255 try:
# --> 256     fd = _os.open(file, flags, 0o600)
#     257 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'c:\\tmpqm0b_jvu'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 from ultralytics import YOLO
#       4 # Load pre-trained YOLOv8 model
#       5 model = YOLO("yolov8n.pt")  # 'n' = nano version, fast and lightweight
#
# File c:\Users\mahma\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ...
